# %% [markdown]
# # 1.2 Saving dataframes into pickle files.
#
# >In this section, we will be using the more restrictive text pre-processing:
#
# >* Porter stemming.
# * Stop words.
#
# >We will be using sklearn NaiveBayes Multinomial.

# %% [markdown]
# We have two possible labels:
#
# `relevance` and `positivity`.
#
# ** Pros of using `relevance`**:
#
# * There's no missing values. Out of 8,000 datapoints, only 9 are coded as `not sure` out of two other possible values `yes`, and `no`. I will reclassify `not sure` as `no`.
#
# * This is a binary classification problem.
#
# ** Cons of using `relevance`**:
#
# * Classes are imbalanced.
#
# ** Pros of using `positivity`**:
#
# * This is a multiclass classification problem.
#
# ** Cons of using `positivity`**:
#
# * We only have 1,420 datapoints out of 8,000 labeled.
#
# * Inputting missing values as the mean introduces bias.
#
# * There's no proper way of trying to recode the missing values as it's based on personal judgments.

# %%
reset -fs

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import string
import re
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import nltk
import nlp_ml_functions
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.preprocessing import label_binarize, MultiLabelBinarizer, binarize
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score, roc_curve, mean_squared_error, r2_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
sns.set_style('white')

# %% [markdown]
# ## Using `relevance` as labels.

# %% [markdown]
# ### Loading dataset into a pandas dataframe.

# %%
economic_df = pd.read_csv('Full-Economic-News-DFE-839861.csv', encoding='utf-8')

# %% [markdown]
# #### Creating a list of new column names.

# %%
new_column_names = ['unit_id', 'golden', 'unit_state', 'trusted_judgments', 'last_judgment_at','positivity', 'positivity_confidence', 'relevance', 'relevance_confidence', 'article_id', 'article_date', 'article_headline', 'positivity_gold', 'relevance_gold', 'article_text']

# %% [markdown]
# #### Renaming columns of dataframe.

# %%
economic_df.columns = new_column_names

# %%
economic_df.shape
# Out:
# (8000, 15)

# %%
economic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 15 columns):
# unit_id                  8000 non-null int64
# golden                   8000 non-null bool
# unit_state               8000 non-null object
# trusted_judgments        8000 non-null int64
# last_judgment_at         8000 non-null object
# positivity               1420 non-null float64
# positivity_confidence    3775 non-null float64
# relevance                8000 non-null object
# relevance_confidence     8000 non-null float64
# article_id               8000 non-null object
# article_date             8000 non-null object
# article_headline         8000 non-null object
# positivity_gold          0 non-null float64
# relevance_gold           0 non-null float64
# article_text             8000 non-null object
# dtypes: bool(1), float64(5), int64(2), object(7)
# memory usage: 882.9+ KB

# %% [markdown]
# ### Clean up.

# %%
economic_df['article_headline'] = economic_df['article_headline'].apply(nlp_ml_functions.strip_tags)

# %%
economic_df['article_text'] = economic_df['article_text'].apply(nlp_ml_functions.strip_tags)

# %%
economic_df['article_headline'] = economic_df['article_headline'].apply(nlp_ml_functions.clean_up_article)

# %%
economic_df['article_text'] = economic_df['article_text'].apply(nlp_ml_functions.clean_up_article)

# %%
economic_df.head()
# Out:
#      unit_id golden unit_state  trusted_judgments    last_judgment_at  \
# 0  842613455  False  finalized                  3  12/5/2015 17:48:27
# 1  842613456  False  finalized                  3  12/5/2015 16:54:25
# 2  842613457  False  finalized                  3  12/5/2015 01:59:03
# 3  842613458  False  finalized                  3  12/5/2015 02:19:39
# 4  842613459  False  finalized                  3  12/5/2015 17:48:27
#
#    positivity  positivity_confidence relevance  relevance_confidence  \
# 0         3.0                 0.6400       yes                 0.640
# 1         NaN                    NaN        no                 1.000
# 2         NaN                    NaN        no                 1.000
# 3         NaN                 0.0000        no                 0.675
# 4         3.0                 0.3257       yes                 0.640
#
#       article_id article_date  \
# 0  wsj_398217788   1991-08-14
# 1  wsj_399019502   2007-08-21
# 2  wsj_398284048   1991-11-14
# 3  wsj_397959018   1986-06-16
# 4  wsj_398838054   2002-10-04
#
#                                     article_headline  positivity_gold  \
# 0              Yields on CDs Fell in the Latest Week              NaN
# 1  The Morning Brief White House Seeks to Limit C...              NaN
# 2  Banking Bill Negotiators Set Compromise Plan t...              NaN
# 3  Managers Journal Sniffing Out Drug Abusers Is ...              NaN
# 4  Currency Trading Dollar Remains in Tight Range...              NaN
#
#    relevance_gold                                       article_text
# 0             NaN  NEW YORK Yields on most certificates of deposi...
# 1             NaN  The Wall Street Journal OnlineThe Morning Brie...
# 2             NaN  WASHINGTON In an effort to achieve banking ref...
# 3             NaN  The statistics on the enormous costs of employ...
# 4             NaN  NEW YORK Indecision marked the dollars tone as...

# %%
economic_df.relevance.value_counts()
# Out:
# no          6571
# yes         1420
# not sure       9
# Name: relevance, dtype: int64

# %% [markdown]
# #### Converting variable `relevance` to numerical values and coding `not sure` as `no`.

# %%
economic_df['relevance'] = economic_df['relevance'].apply(lambda x: 1 if x == 'yes' else 0)

# %%
economic_df.relevance.value_counts()
# Out:
# 0    6580
# 1    1420
# Name: relevance, dtype: int64

# %% [markdown]
# #### The labels/classes are clearly unbalanced.

# %%
economic_df.relevance.value_counts()*100/len(economic_df.relevance)
# Out:
# 0    82.25
# 1    17.75
# Name: relevance, dtype: float64

# %% [markdown]
# >We will experiment building models with the above class unbalance. However, we will making a new dataframe with 50% of each class.
#
# We will sample 1,200 rows of the majority class, and another 1,200 of the minority class by sampling 4 times such class with replacement.

# %% [markdown]
# #### Example of getting 1200 samples of relevance `0`.

# %%
economic_df[economic_df['relevance'] == 0].sample(n=1200)
# Out:
#         unit_id golden unit_state  trusted_judgments     last_judgment_at  \
# 1908  842615368  False  finalized                  3   12/4/2015 23:09:23
# 5305  830982935  False  finalized                  3  11/18/2015 07:40:43
# 4369  830981998  False  finalized                  3  11/18/2015 10:23:15
# 2630  842616091  False  finalized                  3   12/5/2015 00:15:45
# 2096  842615556  False  finalized                  3   12/5/2015 08:24:48
# 4258  830981887  False  finalized                  3  11/18/2015 12:21:12
# 3062  842616524  False  finalized                  3   12/5/2015 10:15:58
# 5049  830982679  False  finalized                  3  11/18/2015 11:16:11
# 2806  842616268  False  finalized                  3   12/5/2015 00:04:18
# 5237  830982867  False  finalized                  3  11/17/2015 23:40:41
# 2257  842615718  False  finalized                  3   12/5/2015 11:35:31
# 432   842613890  False  finalized                  3   12/5/2015 11:35:46
# 5257  830982887  False  finalized                  3  11/17/2015 20:47:14
# 5985  830983615  False  finalized                  3  11/18/2015 11:05:28
# 5257   wapo_409143487   2001-03-26
# 5985   wapo_409047195   2000-09-21
# 879    wsj_1445876626   2013-10-28
# 1812    wsj_398846138   2003-02-28
# 5149   wapo_138680623   1985-03-25
# 6731   wapo_147114362   1980-07-18
# 5225   wapo_148038085   1971-01-02
# 6326   wapo_146635467   1977-10-07
# 6464   wapo_147560301   1982-02-05
# 2645    wsj_398961521   2005-08-25
# 1072    wsj_397880033   1984-12-11
# 4636   wapo_307063668   1988-09-27
# 7085   wapo_149010423   1958-06-28
# 295     wsj_398110037   1988-04-06
# 88     wsj_1037495849   2012-09-01
# 2190    wsj_399127563   2010-04-12
# 1661    wsj_398220303   1990-06-11
# 1378    wsj_237972470   2010-03-11
# ...               ...          ...
# 4480   wapo_140269909   1990-07-19
# 4514   wapo_306957818   1987-11-26
# 6798   wapo_307503371   1992-02-07
# 4108  wapo_1455076179   1997-05-01
# 4987   wapo_152485032   1952-01-18
# 7918   wapo_147087546   1980-09-28
# 1701    wsj_399061719   2007-11-07
# 6978   wapo_152607494   1953-03-11
# 1824    wsj_398980053   2007-04-11
# 7603   wapo_148641012   1955-01-02
# 3790    wsj_399090425   2007-06-18
# 5441   wapo_409368106   2002-07-06
# 3305   wsj_1417539895   2013-08-03
# 808     wsj_398785838   2000-10-17
# 4554   wapo_139931410   1989-09-16
# 1447    wsj_398746041   1999-04-02
# 2703    wsj_399034841   2008-03-10
# 4587   wapo_146872156   1978-07-20
# 2456   wsj_1535597938   2014-06-16
# 3803    wsj_896364398   2011-10-06
# 5957   wapo_410071753   2006-10-25
# 6425   wapo_409160209   2001-09-29
# 3422    wsj_398221718   1989-11-09
# 5014   wapo_146863441   1978-02-23
# 7487   wapo_146412841   1976-09-24
# 2196    wsj_398901024   2005-02-11
# 2089    wsj_398876658   1998-06-25
# 7723   wapo_409481076   2003-08-16
# 7799   wapo_408619928   2000-07-27
# 3005    wsj_867449685   2011-05-19
#
#                                        article_headline  positivity_gold  \
# 1908  Insurers Brace for Disability Claims Tied to S...              NaN
# 5305  Debate Over Jobless Benefits Resonates Near an...              NaN
# 4369  Business Outlook Reserve Board Doesn t Discour...              NaN
# 2630  When You Own Your Own Abode Bad Real Estate Ne...              NaN
# 2096  Recession Is Over a Few Bulls Say Bucking Fiel...              NaN
# 4258  Greenspan Sees Signs Of Asian Ripple Effect Co...              NaN
# 3062  Fed Examiners Sent to Audit Maryland S amp L C...              NaN
# 5049  Stocks Roar Ahead as Report Shows Economic Muscle              NaN
# 2806  Argentinas Peso Dollar Peg Is a Drag On Effort...              NaN
# 5237                         A Voice Of Trade Rebellion              NaN
# 2257  Credit markets Price of 30 year Treasury bond ...              NaN
# 432   Corporate News GE Points to Recovery Despite P...              NaN
# 5257        An Imploding Telecom Sector Tests Darwinism              NaN
# 5985  An Office Closer to Home Area Centers Offer Em...              NaN
# 879   Valuing Twitter vs Facebook Which IPO Is the C...              NaN
# 1812  White Houses Medicare Plan Expands Focus on Dr...              NaN
# 5149  Jobless Aid Cut Sought Reagan Finds Retraining...              NaN
# 6731                                             I 6 n               NaN
# 5225  Bond Prices Drift Down Phone Issue Due Heavy C...              NaN
# 6326  Okun Breaks With Carter On Economy Okun Splits...              NaN
# 6464  Volcker to Tell Hill Fed Sticking to Its Guns ...              NaN
# 2645               EDS Negotiations to Sell Unit Fizzle              NaN
# 1072  Britains Saatchis Have Hustled Their Way Into ...              NaN
# 4636  Dollar Higher Despite Inverventions by Central...              NaN
# 7085                              Aluminum Shares Slump              NaN
# 295   Who Should ve Been This Presidents Men The Bes...              NaN
# 88    The Federal Reserve From Central Bank to Centr...              NaN
# 2190  Whats Ahead People amp Events to Watch in the ...              NaN
# 1661                                         World Wire              NaN
# 1378  U S Sees Brisk Auction Demand Huge Deficit Low...              NaN
# ...                                                 ...              ...
# 4480  21 000 Get Furlough Notices Clarke Plans Sessi...              NaN
# 4514  Income Rises 1 7 Percent In October Farm Subsi...              NaN
# 6798  Kelly Seeks New Taxes To Fill Gap Richest Resi...              NaN
# 4108              Dow Rises 47 Closing Above 7000 Again              NaN
# 4987           Rails and Oils Lead Renewed Stock Upturn              NaN
# 7918                            T1 C IVnsIjington JJost              NaN
# 1701                       Business World I m Lovin GM               NaN
# 6978                          Early Losses Close Higher              NaN
# 1824            D R Horton Posts 37 Drop In Home Orders              NaN
# 7603               Keep Inflation Dead Goal of Humphrey              NaN
# 3790          Options Signal Wake Up Call On Stock Risk              NaN
# 5441  Jobless Report Shows Rebound Has Weakened Unem...              NaN
# 3305                      More Doctors Leaving Medicare              NaN
# 808   Tuition Continues to Outpace Inflation Rising ...              NaN
# 4554  Economic Fears Eased By Reports Producer Price...              NaN
# 1447  Small Stock Focus Tech Rally Sends Small Caps ...              NaN
# 2703  Forex View As Dollar Drops to Low Is an Interv...              NaN
# 4587              UAW Chief Quits Labor Management Unit              NaN
# 2456  China Tops U S in Corporate Debt Issuance S am...              NaN
# 3803            Credit Card Company Stocks Charge Ahead              NaN
# 5957  How Much Is Too Much Fed Looks for Its Comfort...              NaN
# 6425  Freedom Forum Scaling Back Media Group Hurt Bi...              NaN
# 3422  Central Capital Tells Fed It Seeks to Boost St...              NaN
# 5014                           Jobless Up in EEC World               NaN
# 7487       At Issue How to Pay for New Federal Programs              NaN
# 2196              WEEKEND JOURNAL Home Prices Our Towns              NaN
# 2089  A Special Background Report On Trends in Indus...              NaN
# 7723  When Locking In a Mortgage Rate Get It in Writing              NaN
# 7799                                     For the Record              NaN
# 3005                      States See New Need for Bonds              NaN
#
#       relevance_gold                                       article_text
# 1908             NaN  Why is MetLife Inc a New York based company wi...
# 5305             NaN  As Virginia gears up for a governors campaign ...
# 4369             NaN  WALL STREET S such a contrary place The Federa...
# 2630             NaN  It is every homeowners worst nightmare that dr...
# 2096             NaN  Corrections amp AmplificationsA SURVEY by Blue...
# 4258             NaN  Federal Reserve Chairman Alan Greenspan said y...
# 3062             NaN  WASHINGTON The Federal Reserve Board sent exam...
# 864   Interest Rates Are Seen Pushing Higher Even Wh...              NaN
# 78                Bernanke Faces Skepticism Over Policy              NaN
# 1303  Warning Signs After Historic Surge Profit Gain...              NaN
# 6359                    Sell Off Sinks Markets At Close              NaN
# 230   Philadelphia Fed Survey Increases Growth Forecast              NaN
# 2317                Why Dollar May Be Set for a Rebound              NaN
# 5639  Publics Personality Seems Split in Its Percept...              NaN
# 771            Venture Capital Forced to Perform Triage              NaN
# 6620  Economy Continues Sluggish Expansion Manufactu...              NaN
# 3237                U S News Industry Picks Up the Pace              NaN
# 940               OCC Data Reaffirm Wall Street Warning              NaN
# 6377                     Dow and Tech Stocks Take a Dip              NaN
# 3045  Cost Cutting Airlines Grapple With Issue of Ex...              NaN
#
#       relevance_gold                                       article_text
# 3395             NaN  NEW YORK Stocks bonds and the dollar all stumb...
# 5292             NaN  The annual report of the presidents Council of...
# 7825             NaN  NEW YORK Jan 27 AP The stock market made a spi...
# 238              NaN  A bounce for beaten down financial stocks push...
# 3839             NaN  WASHINGTON A dive in orders for big ticket fac...
# 2667             NaN  NEW YORK The dollar fell against the yen and e...
# 2774             NaN  NEW YORK Treasury prices ended lower after Fed...
# 2116             NaN  Dow Jones NewswiresWASHINGTON There are signs ...
# 2115             NaN  NEW YORK Bonds that take their cues from the s...
# 2015             NaN  NEW YORK Small was beautiful in August as micr...
# 3984             NaN  WASHINGTON Rising energy costs pushed U S cons...
# 897              NaN  HURRICANE KATRINA IS forcing professional inve...
# 6794             NaN  Fairfax County still reeling from the recessio...
# 4007             NaN  Retail sales slipped 0 1 percent in February a...
# 620              NaN  New York City which has spent most of the past...
# 3441             NaN  THE STOCK MARKET STAGED one of its biggest dec...
# 2952             NaN  The one week old rally broadened yesterday as ...
# 3181             NaN  WASHINGTON The U S trade deficit hit another r...
# 1030             NaN   Todays Market Forecast Out of OrderInvestors ...
# 377              NaN  So called safe harbor flows have meant strong ...
# 327              NaN  WASHINGTON The Conference Boards index of lead...
# 185              NaN  Global stocks tumbled on Friday dragging the D...
# 698              NaN  The continuing rally in Treasury bonds drove s...
# 3717             NaN  WASHINGTON The U S trade deficit swelled to 11...
# 6428             NaN  Troubled waters of the Bay of Tonkin rippled t...
# 1066             NaN  A 220 BILLION PLUS weight could be lifting at ...
# 2229             NaN  Dow Jones NewswiresDANA CORP S DISMAL third qu...
# 5313             NaN  CHICAGO As Illinois Gov George Ryan decides wh...
# 414              NaN  The bears went on the offensive in the Treasur...
# 7894             NaN  After two months in which bad weather held dow...
# ...              ...                                                ...
# 2027             NaN  A burst of higher inflation is fueling debate ...
# 995              NaN  Banks are boosting their lending to businesses...
# 80               NaN  ST PETERSBURG Fla Use of stock options contrac...
# 5289             NaN  Budget director David A Stockman in an unusual...
# 3316             NaN  Earnings at several major banks rebounded from...
# 1811             NaN  WASHINGTON With few clear signs of economic re...
# 4096             NaN  Consider casual drug users and what some of Ma...
# 3492             NaN  NEW YORK Rite Aid Corp posted a wider fiscal s...
# 1672             NaN  Even amoebas learn by trial and error but some...
# 3714             NaN  Stock prices soared as the nations banks bowed...
# 6891             NaN  NEW YORK Sept 15 UP The stock market resumed i...
# 3903             NaN  President Obama didnot comment on Fridays repo...
# 3604             NaN  Shares of young technology companies fell furt...
# 483              NaN  WASHINGTON Construction of new homes fell shar...
# 167              NaN  WASHINGTON The number of contracts signed to b...
# 1717             NaN  U S stock futures pared their premarket gains ...
# 3339             NaN  Fridays official report on the U S labor marke...
# 864              NaN  NEW YORK Interest rates are likely to push hig...
# 78               NaN  JACKSON HOLE Wyo Ben Bernanke encountered a he...
# 1303             NaN  Brace yourself Over the next several weeks hun...
# 6359             NaN  A burst of selling in the final minutes of a v...
# 230              NaN  WASHINGTON Forecasters surveyed quarterly by t...
# 2317             NaN  Beating down the dollar has become a popular s...
# 5639             NaN  President Reagan s economic policies are unfai...
# 771              NaN  OAKLAND Calif Claremont Creek Ventures recentl...
# 6620             NaN  U S manufacturing grew more slowly in August a...
# 3237             NaN  Manufacturing activity gained steam on several...
# 940              NaN  WASHINGTON A U S regulator said banks trading ...
# 6377             NaN  NEW YORK June 21 Stock prices closed mixed tod...
# 3045             NaN  A HARSH DOWNDRAFT grips the U S airline indust...
#
# [300 rows x 15 columns]

# %% [markdown]
# >Now, let's create a new dataframe with the balanced sampling:

# %%
frames = []
for i in range(5):
    if i < 4:
        frames.append(economic_df[economic_df['relevance'] == 1].sample(n=300, replace=True))
    else:
        frames.append(economic_df[economic_df['relevance'] == 0].sample(n=1200, replace=False))
    
balanced_df = pd.concat(frames)

# %%
balanced_df.relevance.value_counts()*100/len(balanced_df.relevance)
# Out:
# 1    50.0
# 0    50.0
# Name: relevance, dtype: float64

# %% [markdown]
# >We have a balanced dataframe to build future models.

# %% [markdown]
# #### Converting variable `unit_state` to numerical values.

# %%
economic_df['unit_state'] = economic_df['unit_state'].apply(lambda x: 1 if x == 'finalized' else 0)

# %%
balanced_df['unit_state'] = balanced_df['unit_state'].apply(lambda x: 1 if x == 'finalized' else 0)

# %% [markdown]
# #### Converting variable `golden` to numerical values.

# %%
economic_df['golden'] = economic_df['golden'].apply(lambda x: 0 if x == False else 1)

# %%
balanced_df['golden'] = balanced_df['golden'].apply(lambda x: 0 if x == False else 1)

# %% [markdown]
# #### Since columns `positivity_gold` and `relevance_gold` are empty, we can drop them.

# %%
del economic_df['positivity_gold']

# %%
del balanced_df['positivity_gold']

# %%
del economic_df['relevance_gold']

# %%
del balanced_df['relevance_gold']

# %% [markdown]
# #### Converting `last_judgment_at` and `article_date` to datetime.

# %%
economic_df['last_judgment_at'] = pd.to_datetime(economic_df['last_judgment_at'])

# %%
balanced_df['last_judgment_at'] = pd.to_datetime(balanced_df['last_judgment_at'])

# %%
economic_df['article_date'] = pd.to_datetime(economic_df['article_date'])

# %%
balanced_df['article_date'] = pd.to_datetime(balanced_df['article_date'])

# %% [markdown]
# ### Saving files for future use.

# %%
economic_df.to_pickle("full_df")

# %%
balanced_df.to_pickle("balanced_df")

# %%
economic_df = pd.read_pickle("full_df")

# %%
balanced_df = pd.read_pickle("balanced_df")

# %% [markdown]
# #### Checking if pickle files load:

# %%
economic_df.head()
# Out:
#      unit_id  golden  unit_state  trusted_judgments    last_judgment_at  \
# 0  842613455       0           1                  3 2015-12-05 17:48:27
# 1  842613456       0           1                  3 2015-12-05 16:54:25
# 2  842613457       0           1                  3 2015-12-05 01:59:03
# 3  842613458       0           1                  3 2015-12-05 02:19:39
# 4  842613459       0           1                  3 2015-12-05 17:48:27
#
#    positivity  positivity_confidence  relevance  relevance_confidence  \
# 0         3.0                 0.6400          1                 0.640
# 1         NaN                    NaN          0                 1.000
# 2         NaN                    NaN          0                 1.000
# 3         NaN                 0.0000          0                 0.675
# 4         3.0                 0.3257          1                 0.640
#
#       article_id article_date  \
# 0  wsj_398217788   1991-08-14
# 1  wsj_399019502   2007-08-21
# 2  wsj_398284048   1991-11-14
# 3  wsj_397959018   1986-06-16
# 4  wsj_398838054   2002-10-04
#
#                                     article_headline  \
# 0              Yields on CDs Fell in the Latest Week
# 1  The Morning Brief White House Seeks to Limit C...
# 2  Banking Bill Negotiators Set Compromise Plan t...
# 3  Managers Journal Sniffing Out Drug Abusers Is ...
# 4  Currency Trading Dollar Remains in Tight Range...
#
#                                         article_text
# 0  NEW YORK Yields on most certificates of deposi...
# 1  The Wall Street Journal OnlineThe Morning Brie...
# 2  WASHINGTON In an effort to achieve banking ref...
# 3  The statistics on the enormous costs of employ...
# 4  NEW YORK Indecision marked the dollars tone as...

# %%
balanced_df.head()
# Out:
#         unit_id  golden  unit_state  trusted_judgments    last_judgment_at  \
# 6446  830984077       0           1                  3 2015-11-17 17:47:53
# 5697  830983327       0           1                  3 2015-11-17 17:36:51
# 5381  830983011       0           1                  3 2015-11-18 10:58:37
# 841   842614300       0           1                  3 2015-12-05 18:21:41
# 6958  830984592       0           1                  3 2015-11-18 11:50:08
#
#       positivity  positivity_confidence  relevance  relevance_confidence  \
# 6446         5.0                 0.3566          1                0.6936
# 5697         4.0                 0.3695          1                0.6634
# 5381         8.0                 0.3333          1                0.6667
# 841          5.0                 0.3431          1                0.6774
# 6958         8.0                 0.3337          1                0.6675
#
#           article_id article_date  \
# 6446  wapo_408523708   1999-10-26
# 5697  wapo_147173705   1980-04-17
# 5381  wapo_408396675   1998-10-03
# 841   wsj_1033526241   2012-08-16
# 6958  wapo_750986740   1994-10-29
#
#                                        article_headline  \
# 6446  Stocks Fall As Bond Yields Rise Dow Closes Off...
# 5697                  Stock Market Grinds to Quick Halt
# 5381  4 Executives At UBS Quit After Internal Fund P...
# 841                     Whats Really in the Ryan Budget
# 6958  Fed Reports Disparity in Area Lending Blacks H...
#
#                                            article_text
# 6446  Stocks closed mostly lower today as revived fe...
# 5697  als that interest rates may have peaked and th...
# 5381  The chairman of UBS AG stepped down today afte...
# 841   Thanks to several years of fiscal restraint du...
# 6958  Blacks and Hispanics in the Washington area we...

# %% [markdown]
# ## Using `positivity` as labels.

# %% [markdown]
# >We only have 1,420 datapoints, so we will drop the missing values (inputting to the mean introduces bias, as we described before).
#
# >`positivity` ranges from `2` to `9`, so we will create two classes: one class grouping from `2` to `5`, and the other one grouping `6` to `9`, which is totally arbitrarely.

# %%
economic_pos_df = economic_df[np.isfinite(economic_df['positivity'])]

# %%
# http://stackoverflow.com/questions/20625582/how-to-deal-with-settingwithcopywarning-in-pandas
pd.options.mode.chained_assignment = None

# %%
economic_pos_df['positivity'] = economic_pos_df['positivity'].apply(lambda x: 1 if x < 6 else 0)

# %%
economic_pos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1420 entries, 0 to 7995
# Data columns (total 13 columns):
# unit_id                  1420 non-null int64
# golden                   1420 non-null int64
# unit_state               1420 non-null int64
# trusted_judgments        1420 non-null int64
# last_judgment_at         1420 non-null datetime64[ns]
# positivity               1420 non-null int64
# positivity_confidence    1420 non-null float64
# relevance                1420 non-null int64
# relevance_confidence     1420 non-null float64
# article_id               1420 non-null object
# article_date             1420 non-null datetime64[ns]
# article_headline         1420 non-null object
# article_text             1420 non-null object
# dtypes: datetime64[ns](2), float64(2), int64(6), object(3)
# memory usage: 155.3+ KB

# %%
economic_pos_df.positivity.value_counts()
# Out:
# 1    838
# 0    582
# Name: positivity, dtype: int64

# %% [markdown]
# #### Check if labels are balanced.

# %%
economic_pos_df.positivity.value_counts()*100/len(economic_pos_df.positivity)
# Out:
# 1    59.014085
# 0    40.985915
# Name: positivity, dtype: float64

# %%
economic_pos_df.to_pickle("positive_df")

# %%
economic_pos_df = pd.read_pickle("positive_df")

# %%
economic_pos_df.head()
# Out:
#       unit_id  golden  unit_state  trusted_judgments    last_judgment_at  \
# 0   842613455       0           1                  3 2015-12-05 17:48:27
# 4   842613459       0           1                  3 2015-12-05 17:48:27
# 5   842613460       0           1                  3 2015-12-04 23:15:05
# 9   842613464       0           1                  3 2015-12-05 18:40:28
# 12  842613467       0           1                  3 2015-12-05 01:29:35
#
#     positivity  positivity_confidence  relevance  relevance_confidence  \
# 0            1                 0.6400          1                0.6400
# 4            1                 0.3257          1                0.6400
# 5            1                 0.6783          1                1.0000
# 9            1                 0.6657          1                1.0000
# 12           1                 0.3388          1                0.6777
#
#        article_id article_date  \
# 0   wsj_398217788   1991-08-14
# 4   wsj_398838054   2002-10-04
# 5   wsj_905654974   2011-11-23
# 9   wsj_397912506   1984-11-01
# 12  wsj_738300385   2010-08-03
#
#                                      article_headline  \
# 0               Yields on CDs Fell in the Latest Week
# 4   Currency Trading Dollar Remains in Tight Range...
# 5                  Stocks Fall Again BofA Alcoa Slide
# 9   U S Dollar Falls Against Most Currencies Decli...
# 12               Defending Yourself Against Deflation
#
#                                          article_text
# 0   NEW YORK Yields on most certificates of deposi...
# 4   NEW YORK Indecision marked the dollars tone as...
# 5   Stocks declined as investors weighed slower th...
# 9   The U S dollar declined against most major for...
# 12  Author James B StewartThe dreaded D word is ba...
